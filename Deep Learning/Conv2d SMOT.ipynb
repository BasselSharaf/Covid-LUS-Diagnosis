# %%
# %matplotlib inline

# %%
import cv2
import os
import math
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from PIL import Image
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
from sklearn import preprocessing
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten,MaxPooling2D,Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import (
    EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
)
from tensorflow.keras.optimizers import Adam,SGD
from imblearn.over_sampling import SMOTE
from collections import Counter
from model_maker import make_model,evaluate_model

# %%
IMAGE_WIDTH=224
IMAGE_HEIGHT=224

# %%
#Load all patients 
my_data = pd.read_csv('../data/Five_Frames_Per_patient.csv')
patients_data=pd.read_csv('../data/videos_data.csv')
data_array = my_data.to_numpy()
patients_array=patients_data["FileName"].to_numpy()
images_path = '../data/Five_Frames_Per_patient/'
no_of_test_patients=math.floor(patients_array.size*0.2) 
images_data = []
models = []

df=my_data
data_array=df.to_numpy()
for i in data_array:
    img = cv2.imread(images_path + i[0] + '.' + i[2], cv2.IMREAD_GRAYSCALE)
    img=  cv2.equalizeHist(img)
    img = cv2.resize(img, (IMAGE_WIDTH, IMAGE_HEIGHT))
    img_2d = img.reshape(IMAGE_WIDTH ,IMAGE_HEIGHT,1)
    images_data.append(img_2d)

X=np.asarray(images_data)
y = np.asarray(my_data['Label'])
print(Counter(y))
# Out:
# Counter({'regular': 280, 'pneumonia': 180, 'covid': 150})

# %%
testPatient_indexes= [1,2,12,14,15,22,
                      33,34,37,42,43,52,53,
                      92,95,96,99,101,102,104,107,110,115,118]
#getting frame indexes of each patient
frames_index=[]
for i in testPatient_indexes:
  j=i*5
  z=j+5
  while j<z:
    frames_index.append(j)
    j+=1

# %%
# Adding the frames to X_test
X_test=np.take(X,frames_index,axis=0)
y_test=np.take(y,frames_index,axis=0)
# Removing the frames from X_train
X_train=np.delete(X,frames_index,axis=0)
y_train=np.delete(y,frames_index,axis=0)

# Scale the pixels
X_train=X_train/255.0
X_test=X_test/255.0

# %%
#Applying SMOTE
oversample = SMOTE()
X_train=np.resize(X_train,(X_train.shape[0],50176))
X_train,y_train=oversample.fit_resample(X_train, y_train)
X_train=np.resize(X_train,(X_train.shape[0],224,224,1))
counter=Counter(y_train)
print(counter)
y_fold=y_train
#Label encode classes to numbers
#One-hot Encode y
number = preprocessing.LabelEncoder()
y_train=number.fit_transform(y_train)
y_train=to_categorical(y_train,3)

number2 = preprocessing.LabelEncoder()
y_test=number2.fit_transform(y_test)
y_test=to_categorical(y_test,3)
# Out:
# Counter({'covid': 225, 'pneumonia': 225, 'regular': 225})

# %%
print('X_train: '+str(X_train.shape))
print('y_train: '+str(y_train.shape))
print('X_test: '+ str(X_test.shape))
print('y_test: '+ str(y_test.shape))
# Out:
# X_train: (675, 224, 224, 1)
# y_train: (675, 3)
# X_test: (120, 224, 224, 1)
# y_test: (120, 3)

# %%
# initialize the training data augmentation object
MODEL_PATH=os.path.join('', "Conv2d-SMOT")

trainAug = ImageDataGenerator(
    rotation_range=10,
    fill_mode='nearest',
    horizontal_flip=True,
    vertical_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)

mcp_save = ModelCheckpoint(
    MODEL_PATH,
    save_best_only=True,
    monitor='val_accuracy',
    mode='max',
    verbose=1
)

# %%
BATCH_SIZE=16
EPOCHS=20
LR=1e-4
opt = Adam(learning_rate=LR,decay=LR / 20)
# Define callbacks
earlyStopping = EarlyStopping(
    monitor='loss',
    patience=20,
    verbose=1,
    mode='min',
    restore_best_weights=True
)


reduce_lr_loss = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.7,
    patience=7,
    verbose=1,
    min_delta=1e-4,
    mode='min'
)

# %%
model=make_model()

# %%
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history=model.fit(
    trainAug.flow(X_train, y_train, batch_size=BATCH_SIZE),
    steps_per_epoch=len(X_train) // BATCH_SIZE,
    validation_data=(X_test, y_test),
    epochs=20,
    callbacks=[earlyStopping, mcp_save, reduce_lr_loss]
)
# Out:
# Epoch 1/20
# 42/42 [==============================] - 8s 99ms/step - loss: 1.0851 - accuracy: 0.4446 - val_loss: 0.9995 - val_accuracy: 0.5583
#
# Epoch 00001: val_accuracy improved from -inf to 0.55833, saving model to Conv2d-SMOT
# INFO:tensorflow:Assets written to: Conv2d-SMOT\assets
# Epoch 2/20
# 42/42 [==============================] - 3s 75ms/step - loss: 0.9326 - accuracy: 0.5781 - val_loss: 0.8577 - val_accuracy: 0.6000
#
# Epoch 00002: val_accuracy improved from 0.55833 to 0.60000, saving model to Conv2d-SMOT
# INFO:tensorflow:Assets written to: Conv2d-SMOT\assets
# Epoch 3/20
# 42/42 [==============================] - 3s 77ms/step - loss: 0.8525 - accuracy: 0.6085 - val_loss: 0.8320 - val_accuracy: 0.6667
#
# Epoch 00003: val_accuracy improved from 0.60000 to 0.66667, saving model to Conv2d-SMOT
# INFO:tensorflow:Assets written to: Conv2d-SMOT\assets
# Epoch 4/20
# 42/42 [==============================] - 3s 71ms/step - loss: 0.8242 - accuracy: 0.6388 - val_loss: 0.7586 - val_accuracy: 0.6833
#
# Epoch 00004: val_accuracy improved from 0.66667 to 0.68333, saving model to Conv2d-SMOT
# INFO:tensorflow:Assets written to: Conv2d-SMOT\assets
# Epoch 5/20
# 42/42 [==============================] - 3s 73ms/step - loss: 0.6988 - accuracy: 0.7223 - val_loss: 0.8347 - val_accuracy: 0.6250
#
# Epoch 00005: val_accuracy did not improve from 0.68333
# Epoch 6/20
# 42/42 [==============================] - 3s 72ms/step - loss: 0.6763 - accuracy: 0.7143 - val_loss: 0.7871 - val_accuracy: 0.6833
#
# Epoch 00006: val_accuracy did not improve from 0.68333
# Epoch 7/20
# 42/42 [==============================] - 3s 70ms/step - loss: 0.5752 - accuracy: 0.7709 - val_loss: 0.6789 - val_accuracy: 0.7500
#
# Epoch 00007: val_accuracy improved from 0.68333 to 0.75000, saving model to Conv2d-SMOT
# INFO:tensorflow:Assets written to: Conv2d-SMOT\assets
# Epoch 8/20
# 42/42 [==============================] - 3s 75ms/step - loss: 0.5588 - accuracy: 0.7876 - val_loss: 0.6279 - val_accuracy: 0.7500
#
# Epoch 00008: val_accuracy did not improve from 0.75000
# Epoch 9/20
# 42/42 [==============================] - 3s 73ms/step - loss: 0.4902 - accuracy: 0.8225 - val_loss: 0.7337 - val_accuracy: 0.7583
#
# Epoch 00009: val_accuracy improved from 0.75000 to 0.75833, saving model to Conv2d-SMOT
# INFO:tensorflow:Assets written to: Conv2d-SMOT\assets
# Epoch 10/20
# 42/42 [==============================] - 3s 72ms/step - loss: 0.4920 - accuracy: 0.7997 - val_loss: 0.5614 - val_accuracy: 0.8167
#
# Epoch 00010: val_accuracy improved from 0.75833 to 0.81667, saving model to Conv2d-SMOT
# INFO:tensorflow:Assets written to: Conv2d-SMOT\assets
# Epoch 11/20
# 42/42 [==============================] - 3s 69ms/step - loss: 0.4290 - accuracy: 0.8209 - val_loss: 0.6115 - val_accuracy: 0.7917
#
# Epoch 00011: val_accuracy did not improve from 0.81667
# Epoch 12/20
# 42/42 [==============================] - 3s 68ms/step - loss: 0.3702 - accuracy: 0.8528 - val_loss: 0.6308 - val_accuracy: 0.8083
#
# Epoch 00012: val_accuracy did not improve from 0.81667
# Epoch 13/20
# 42/42 [==============================] - 3s 69ms/step - loss: 0.3198 - accuracy: 0.8892 - val_loss: 0.7407 - val_accuracy: 0.8167
#
# Epoch 00013: val_accuracy did not improve from 0.81667
# Epoch 14/20
# 42/42 [==============================] - 3s 73ms/step - loss: 0.2960 - accuracy: 0.8847 - val_loss: 0.7748 - val_accuracy: 0.8167
#
# Epoch 00014: val_accuracy did not improve from 0.81667
# Epoch 15/20
# 42/42 [==============================] - 3s 71ms/step - loss: 0.2597 - accuracy: 0.9120 - val_loss: 0.6397 - val_accuracy: 0.8500
#
# Epoch 00015: val_accuracy improved from 0.81667 to 0.85000, saving model to Conv2d-SMOT
# INFO:tensorflow:Assets written to: Conv2d-SMOT\assets
# Epoch 16/20
# 42/42 [==============================] - 3s 71ms/step - loss: 0.2500 - accuracy: 0.9074 - val_loss: 0.6867 - val_accuracy: 0.7917
#
# Epoch 00016: val_accuracy did not improve from 0.85000
# Epoch 17/20
# 42/42 [==============================] - 3s 73ms/step - loss: 0.2910 - accuracy: 0.8923 - val_loss: 0.7662 - val_accuracy: 0.8000
#
# Epoch 00017: val_accuracy did not improve from 0.85000
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 6.999999823165126e-05.
# Epoch 18/20
# 42/42 [==============================] - 3s 73ms/step - loss: 0.2275 - accuracy: 0.9256 - val_loss: 0.7436 - val_accuracy: 0.8000
#
# Epoch 00018: val_accuracy did not improve from 0.85000
# Epoch 19/20
# 42/42 [==============================] - 3s 72ms/step - loss: 0.2083 - accuracy: 0.9241 - val_loss: 0.6156 - val_accuracy: 0.7917
#
# Epoch 00019: val_accuracy did not improve from 0.85000
# Epoch 20/20
# 42/42 [==============================] - 3s 69ms/step - loss: 0.1916 - accuracy: 0.9332 - val_loss: 0.7877 - val_accuracy: 0.7917
#
# Epoch 00020: val_accuracy did not improve from 0.85000

# %%
evaluate_model(model,history,X_train,y_train,X_test,y_test)
# Out:
# Train: 0.953, Test: 0.792
#               precision    recall  f1-score   support
#
#        Covid       1.00      0.70      0.82        30
#    Pneumonia       0.67      0.80      0.73        35
#      Healthy       0.81      0.84      0.82        55
#
#     accuracy                           0.79       120
#    macro avg       0.82      0.78      0.79       120
# weighted avg       0.81      0.79      0.79       120
#
# [[21  5  4]
#  [ 0 28  7]
#  [ 0  9 46]]

# %%
from mostCommon import most_common,patient_score
y_pred=model.predict(X_test)
prediction = np.argmax(y_pred, axis=1)
real=np.argmax(y_test, axis=1)
patient_score(real,prediction)
# Out:
# [[ 4  1  1]
#  [ 0  6  1]
#  [ 0  1 10]]
#               precision    recall  f1-score   support
#
#            0      1.000     0.667     0.800         6
#            1      0.750     0.857     0.800         7
#            2      0.833     0.909     0.870        11
#
#     accuracy                          0.833        24
#    macro avg      0.861     0.811     0.823        24
# weighted avg      0.851     0.833     0.832        24

# %%
# MLP for Pima Indians Dataset with 10-fold cross validation
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import StratifiedKFold


# define 10-fold cross validation test harness
kfold = StratifiedKFold(n_splits=5, shuffle=False)
cvscores = []
for train, test in kfold.split(X_train, y_fold):
  # create model
    model=make_model()
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

    print('hi')
    model.fit(X_train[train], y_train[train], epochs=15, batch_size=30, verbose=0)
    # evaluate the model
    scores = model.evaluate(X_train[test], y_train[test], verbose=0)
    print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1] * 100)
print("%.2f%% (+/- %.2f%%)" % (np.mean(cvscores), np.std(cvscores)))
# Out:
# hi
# accuracy: 80.00%
# hi
# accuracy: 91.85%
# hi
# accuracy: 71.85%
# hi
# accuracy: 98.52%
# hi
# accuracy: 94.07%
# 87.26% (+/- 9.84%)
